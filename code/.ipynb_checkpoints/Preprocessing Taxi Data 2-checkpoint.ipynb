# %% [markdown]
# In order to handle an issue where writing in parquet files resulted in a memory error, the files were read in as csv, had preprocessing applied to them and then written to another parquet file.

# %%
# Importing and starting a spark session
from pyspark.sql import SparkSession
from pyspark import SparkContext
#Supress warnings
spark = SparkSession.builder.getOrCreate()
sc = SparkContext.getOrCreate()
sc.setLogLevel('WARN')

spark.conf.set('spark.sql.execution.arrow.pyspark.enabled', True)
#Make the spark files present well
spark.conf.set('spark.sql.repl.eagerEval.enabled', True)
# Out:
# 21/08/10 00:44:45 WARN Utils: Your hostname, LAPTOP-D5HGLKLK resolves to a loopback address: 127.0.1.1; using 172.23.50.214 instead (on interface eth0)
# 21/08/10 00:44:45 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 21/08/10 00:44:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 21/08/10 00:44:48 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
# reference from Akira Wang's Github
#forming a schema for the dataframes
import pyspark.sql.functions as F
from pyspark.sql.types import *
from pyspark.sql.functions import col

#setting datatypes for each individual column
ints = ('VendorID', 'passenger_count', 'RateCodeID', 'RatecodeID','payment_type', 'PULocationID', 'DOLocationID')
doubles = ('trip_distance', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount'
          , 'congestion_surcharge')
strings = ('store_and_fwd_flag',)
dtimes = ('tpep_pickup_datetime', 'tpep_dropoff_datetime')


dtypes = {column: IntegerType() for column in ints}
dtypes.update({column: DoubleType() for column in doubles})
dtypes.update({column: StringType() for column in strings})
dtypes.update({column: TimestampType() for column in dtimes})

taxi_dir = "../raw_data/yellow_tripdata_20"
#Using a dataset to form the schema
sdf = spark.read.csv(f"{taxi_dir}18-01.csv", header = True)

schema = StructType()
for column in sdf.columns:
    schema.add(column, # column name
               dtypes[column], # data type
               True # is nullable?
              )
#importing the taxi datasets in dictionaries with schemas


taxi18 = {str(i).zfill(2): spark.read.csv(f"{taxi_dir}18-{str(i).zfill(2)}.csv",
                                                     header = True, schema = schema) for i in range(1, 13)}
taxi19 = {str(i).zfill(2): spark.read.csv(f"{taxi_dir}19-{str(i).zfill(2)}.csv",
                                                     header = True, schema = schema) for i in range(1, 13)}
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]

# %%
from pyspark.sql.functions import *
#summarising all the 2018 and 2019 data into dataframes
taxi_2018 = taxi18['01']
taxi_2019 = taxi19['01']
for i in range(2, 13):
    taxi_2018 = taxi_2018.union(taxi18[str(i).zfill(2)])
    taxi_2019 = taxi_2019.union(taxi18[str(i).zfill(2)])

# %%
def preprocessing(dataset) :
    #filter out all payment types not credit card
    dataset = dataset.filter(dataset.payment_type == 1)

    #filter out all payment types that involve Newark Airport
    dataset = dataset.filter(dataset.PULocationID != 1)
    dataset = dataset.filter(dataset.DOLocationID != 1)

    #filter out all negative trip distances
    dataset = dataset.filter(dataset.trip_distance > 0)

    #remove all ratecodes not contained within New York City
    dataset = dataset.filter((dataset.RatecodeID != 3) & (dataset.RatecodeID != 4) & 
                             (dataset.RatecodeID != 99))

    #remove all LocationIDs that are unexplained (posed to be out of state)
    dataset = dataset.filter((dataset.PULocationID != 264) & (dataset.PULocationID != 265)
                            & (dataset.DOLocationID != 264) & (dataset.DOLocationID != 265))

    #remove all trips not in 2018
    dataset = dataset.filter(year(dataset.tpep_pickup_datetime) == 2018)

    #creating a new column corresponding to trip duration in minutes
    dataset = dataset.withColumn("trip_duration", 
                                (unix_timestamp(dataset.tpep_dropoff_datetime) - 
                                unix_timestamp(dataset.tpep_pickup_datetime))/60)

    #filter out all negative trip durations
    dataset = dataset.filter(dataset.trip_duration > 0)
    
    #filter out all non-positive fare and total amounts, and all negative payment amounts
    dataset = dataset.filter((dataset.tolls_amount >= 0) & (dataset.fare_amount > 0)
                            & (dataset.extra >= 0) & (dataset.mta_tax >= 0)
                            & (dataset.improvement_surcharge >= 0) & (dataset.total_amount > 0)
                            & (dataset.tip_amount >= 0))
    
    #drop out all columns that are not of interest
    dataset = dataset.drop(*('VendorID', 'fare_amount', 'extra', 
                             'mta_tax', 'tolls_amount', 'total_amount',
                            'improvement_surcharge', 'payment_type',
                            'store_and_fwd_flag'))
    dataset = dataset.withColumnRenamed('tpep_pickup_datetime', 'pickup_time') \
    .withColumnRenamed('tpep_dropoff_datetime', 'dropoff_time')
    return dataset

# %%
taxi_2018 = preprocessing(taxi_2018)
taxi_2019 = preprocessing(taxi_2019)

# %%
#writing the data into a parquet file
taxi_2018.write.format('parquet').save('../preprocessed_data/preprocessed_taxi_2018.parquet')
taxi_2019.write.format('parquet').save('../preprocessed_data/preprocessed_taxi_2019.parquet')
# Out:
# 21/08/10 00:45:14 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:45:14 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:47:03 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:47:04 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:47:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:47:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:47:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:47:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:47:09 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:47:09 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:47:09 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:47:09 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:47:09 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:47:09 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:47:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:47:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:47:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:47:11 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:49:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:49:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:49:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:49:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:49:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:49:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:49:11 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:49:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:49:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:49:14 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:49:16 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:49:16 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:51:33 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:51:33 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:51:35 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:51:35 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:51:36 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:51:36 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:51:36 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:51:38 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:51:38 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:51:41 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:51:41 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:51:42 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:51:43 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:51:43 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:51:43 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:53:38 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:53:38 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:53:39 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:53:39 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:53:40 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:53:40 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:53:40 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:53:40 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:53:40 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:53:41 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:53:41 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:53:43 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:53:43 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:53:43 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:53:43 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:55:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:55:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:55:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:55:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:55:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:55:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:55:31 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:55:31 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:55:31 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:55:31 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:55:32 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:55:32 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:55:33 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:55:34 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:57:20 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:57:20 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:57:20 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:57:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:57:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:57:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:57:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:57:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:57:22 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:57:22 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:57:22 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:57:23 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:57:23 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:57:23 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:57:23 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:58:50 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:58:51 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:58:52 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:58:52 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:58:53 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:58:53 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:58:54 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:58:54 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:58:54 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:58:54 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:58:54 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 00:58:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 00:58:56 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:00:24 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:00:24 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:00:24 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:00:24 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:00:26 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:00:26 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:00:26 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:00:26 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:00:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:00:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:00:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:00:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:00:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:02:25 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:02:26 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:02:26 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:02:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:02:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:02:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:02:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:02:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:02:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:02:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:02:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:02:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:02:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:02:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:04:25 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:04:25 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:04:25 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:04:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:04:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:04:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:04:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:04:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:04:30 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:04:30 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:04:30 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:04:30 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:04:31 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:04:31 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:06:18 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:06:18 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:06:19 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:06:19 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:06:19 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:06:20 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:06:20 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:06:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:06:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:06:23 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:06:23 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:06:23 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:06:23 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:06:24 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:06:24 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:07:54 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:09:32 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:09:32 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:09:33 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:09:33 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:11:32 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:11:32 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:11:33 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:11:33 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:11:36 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:11:36 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:11:36 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:11:37 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:11:37 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:11:37 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:11:37 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:11:37 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:11:37 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:11:37 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:11:38 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:11:38 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:13:47 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:13:47 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:13:49 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:13:49 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:13:49 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:13:49 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:13:52 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:13:52 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:13:53 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:13:53 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:13:53 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:13:53 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:13:53 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:13:54 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:13:54 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:15:52 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:15:52 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:15:53 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:15:53 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:15:53 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:15:54 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:15:54 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:15:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:15:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:15:57 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:15:58 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:15:58 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:15:58 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:15:58 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:18:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:18:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:18:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:18:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:18:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:18:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:18:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:18:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:18:14 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:18:14 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:18:14 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:18:17 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:18:17 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:18:18 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:18:18 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:20:17 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:20:17 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:20:19 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:20:19 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:20:20 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:20:20 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:20:20 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:20:20 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:20:20 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:20:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:20:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:20:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:20:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:20:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:20:22 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:20:22 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:22:06 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:22:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:22:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:22:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:22:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:22:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:22:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:22:09 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:22:09 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:22:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:22:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:22:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:22:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:22:11 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:22:11 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:24:00 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:24:00 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:24:01 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:24:01 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:24:02 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:24:02 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:24:04 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:24:04 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:24:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:24:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:24:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:24:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:24:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:24:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:24:06 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:24:06 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:26:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:26:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:26:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:26:14 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:26:14 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:26:14 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:26:15 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:26:15 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:26:16 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:26:16 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:26:17 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:26:18 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:26:19 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:26:20 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:26:20 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:28:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:28:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:28:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:28:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:28:09 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:28:09 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:28:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:28:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:28:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:28:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:28:11 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:28:11 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:28:12 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:28:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:28:16 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:28:16 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:29:59 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:29:59 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:30:01 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:30:01 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:30:01 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:30:01 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:30:02 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:30:02 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:30:02 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:30:02 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:30:03 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:30:03 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:30:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:30:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:30:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/10 01:30:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/10 01:32:02 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
