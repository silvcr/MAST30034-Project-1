# %%
#importing census data and census tracts data
import pandas as pd

directory = "../raw_data_lite/"

census_tracts = pd.read_excel(f"{directory}nyc2010census_tabulation_equiv.xlsx")
census_1year = pd.read_csv(f"{directory}ACSDP1Y2018.DP03_data_with_overlays_2021-08-03T213532.csv")
census_5year = pd.read_csv(f"{directory}ACSDP5Y2018.DP03_data_with_overlays_2021-08-03T221820.csv")
# Out:
# /home/binhducvu/jupyterenv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (2,3,4,6,7,10,11,14,15,18,19,22,23,26,27,30,31,32,38,39,40,42,43,46,47,50,51,54,55,56,58,59,62,63,64,66,67,70,71,72,74,75,78,79,82,83,86,87,90,91,94,95,102,103,104,106,107,110,111,114,115,118,119,122,123,126,127,128,130,131,134,135,138,139,142,143,146,147,150,151,154,155,158,159,162,163,166,167,170,171,174,175,178,179,182,183,184,186,187,190,191,194,195,198,199,202,203,204,206,207,210,211,214,215,218,219,222,223,226,227,230,231,234,235,238,239,242,243,254,255,262,263,270,271,278,279,286,287,294,295,298,299,300,302,303,306,307,310,311,314,315,318,319,322,323,326,327,330,331,334,335,338,339,354,355,356,378,379,380,382,383,386,387,390,391,394,395,398,399,400,402,403,406,407,408,410,411,412,414,415,416,418,419,422,423,426,427,430,431,434,435,436,438,439,442,443,446,447,450,451,454,455,456,458,459,462,463,466,467,470,471) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # Preprocessing the data

# %%
#getting all the necessary geojson files

import geopandas as gpd
#converting the NTA and taxi zones data into geojson files
directory = "../raw_data_lite/"
taxi_zones_shp = gpd.read_file(f"{directory}taxi_zones.shp")
taxi_zones_shp.to_file(f"{directory}taxi_zones.geojson", drivers = 'GeoJSON')

nta_shp = gpd.read_file(f"{directory}nynta_21b/nynta.shp")
nta_shp.to_file(f"{directory}nta.geojson", drivers = 'GeoJSON')
#reading the files in as dataframes
taxi_zones = gpd.read_file(f"{directory}taxi_zones.geojson")
nta = gpd.read_file(f"{directory}nta.geojson")
boroughs = gpd.read_file(f"{directory}Borough Boundaries.geojson")
# Out:
# /home/binhducvu/jupyterenv/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %%
import numpy as np

#replacing all unavailable data with np.NaN for type consistency
census_1year.replace('(X)', np.nan)
census_5year.replace('(X)', np.nan)
# Out:
#                     GEO_ID                                            NAME  \
# 0                       id                            Geographic Area Name
# 1     1400000US36005000100          Census Tract 1, Bronx County, New York
# 2     1400000US36005000200          Census Tract 2, Bronx County, New York
# 3     1400000US36005000400          Census Tract 4, Bronx County, New York
# 4     1400000US36005001600         Census Tract 16, Bronx County, New York
# ...                    ...                                             ...
# 2163  1400000US36085030302  Census Tract 303.02, Richmond County, New York
# 2164  1400000US36085031901  Census Tract 319.01, Richmond County, New York
# 2165  1400000US36085031902  Census Tract 319.02, Richmond County, New York
# 2166  1400000US36085032300     Census Tract 323, Richmond County, New York
# 2167  1400000US36085990100    Census Tract 9901, Richmond County, New York
#
#                                              DP03_0001E  \
# 0     Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                                  7080
# 2                                                  3684
# 3                                                  4689
# 4                                                  4598
# ...                                                 ...
# 2163                                               4852
# 2164                                               2107
# 2165                                               3716
# 2166                                                939
# 2167                                                  0
#
#                                              DP03_0001M  \
# 0     Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                                   290
# 2                                                   491
# 3                                                   425
# 4                                                   351
# ...                                                 ...
# 2163                                                447
# 2164                                                322
# 2165                                                379
# 2166                                                152
# 2167                                                 12
#
#                                             DP03_0001PE  \
# 0     Percent Estimate!!EMPLOYMENT STATUS!!Populatio...
# 1                                                  7080
# 2                                                  3684
# 3                                                  4689
# 4                                                  4598
# ...                                                 ...
# 2163                                               4852
# 2164                                               2107
# 2165                                               3716
# 2166                                                939
# 2167                                                  0
#
#                                             DP03_0001PM  \
# 0     Percent Margin of Error!!EMPLOYMENT STATUS!!Po...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2163                                                NaN
# 2164                                                NaN
# 2165                                                NaN
# 2166                                                NaN
# 2167                                                NaN
#
#                                              DP03_0002E  \
# 0     Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                                     0
# 2                                                  1873
# 3                                                  3052
# 4                                                  2477
# ...                                                 ...
# 2163                                               2961
# 2164                                                818
# 2165                                               1946
# 2166                                                527
# 2167                                                  0
#
#                                              DP03_0002M  \
# 0     Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                                    17
# 2                                                   296
# 3                                                   385
# 4                                                   266
# ...                                                 ...
# 2163                                                367
# 2164                                                245
# 2165                                                339
# 2166                                                141
# 2167                                                 12
#
#                                             DP03_0002PE  \
# 0     Percent Estimate!!EMPLOYMENT STATUS!!Populatio...
# 1                                                   0.0
# 2                                                  50.8
# 3                                                  65.1
# 4                                                  53.9
# ...                                                 ...
# 2163                                               61.0
# 2164                                               38.8
# 2165                                               52.4
# 2166                                               56.1
# 2167                                                  -
#
#                                             DP03_0002PM  ...  \
# 0     Percent Margin of Error!!EMPLOYMENT STATUS!!Po...  ...
# 1                                                   0.5  ...
# 2                                                   6.7  ...
# 3                                                   5.1  ...
# 4                                                   4.5  ...
# ...                                                 ...  ...
# 2163                                                6.1  ...
# 2164                                                7.9  ...
# 2165                                                6.9  ...
# 2166                                               12.3  ...
# 2167                                                 **  ...
#
#                                             DP03_0135PE  \
# 0     Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                                     -
# 2                                                  12.5
# 3                                                  14.4
# 4                                                  22.9
# ...                                                 ...
# 2163                                                7.7
# 2164                                               60.7
# 2165                                               43.5
# 2166                                                0.0
# 2167                                                  -
#
#                                             DP03_0135PM  \
# 0     Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                    **
# 2                                                   7.3
# 3                                                   9.3
# 4                                                   9.7
# ...                                                 ...
# 2163                                                9.3
# 2164                                               18.9
# 2165                                               20.8
# 2166                                               26.1
# 2167                                                 **
#
#                                              DP03_0136E  \
# 0     Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2163                                                NaN
# 2164                                                NaN
# 2165                                                NaN
# 2166                                                NaN
# 2167                                                NaN
#
#                                              DP03_0136M  \
# 0     Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2163                                                NaN
# 2164                                                NaN
# 2165                                                NaN
# 2166                                                NaN
# 2167                                                NaN
#
#                                             DP03_0136PE  \
# 0     Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                                     -
# 2                                                  16.2
# 3                                                   7.3
# 4                                                  21.2
# ...                                                 ...
# 2163                                               17.2
# 2164                                               41.1
# 2165                                               33.8
# 2166                                               19.4
# 2167                                                  -
#
#                                             DP03_0136PM  \
# 0     Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                    **
# 2                                                  10.0
# 3                                                   4.7
# 4                                                   8.7
# ...                                                 ...
# 2163                                                7.4
# 2164                                               12.6
# 2165                                               12.2
# 2166                                               15.5
# 2167                                                 **
#
#                                              DP03_0137E  \
# 0     Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2163                                                NaN
# 2164                                                NaN
# 2165                                                NaN
# 2166                                                NaN
# 2167                                                NaN
#
#                                              DP03_0137M  \
# 0     Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2163                                                NaN
# 2164                                                NaN
# 2165                                                NaN
# 2166                                                NaN
# 2167                                                NaN
#
#                                             DP03_0137PE  \
# 0     Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                                     -
# 2                                                  48.8
# 3                                                  21.5
# 4                                                  28.9
# ...                                                 ...
# 2163                                                8.2
# 2164                                               89.4
# 2165                                               58.7
# 2166                                               38.6
# 2167                                                  -
#
#                                             DP03_0137PM
# 0     Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                    **
# 2                                                  11.3
# 3                                                  10.9
# 4                                                  10.2
# ...                                                 ...
# 2163                                                6.7
# 2164                                                8.7
# 2165                                               17.6
# 2166                                               24.4
# 2167                                                 **
#
# [2168 rows x 550 columns]

# %%
#Cut out the first 4 redundant rows
census_tracts = census_tracts.iloc[4:,:]

# %%
#Create a dictionary for tract code -> nta code (county in col 0, code in col 3, nta in col 4)
tracts_to_nta = {}

for index, row in census_tracts.iterrows():
    # The dictionary format is (County, Code) : NTA Code to handle repeating codes
    # in different counties
    tracts_to_nta[(row['Unnamed: 0'], row['Unnamed: 3'])] = row['Unnamed: 5']

# %%
#Forming a header and their respective IDs from columns of interest, done by inspection
# of original dataset - no mapping guide available. All estimates and margin of errors
# are taken in place of percent estimates as we need to aggregate certain tracts

header = ['GEO_ID', 'Name', 
         'Civilian labor force estimates', 'Civilian labor force error',
         'Unemployment estimates', 'Unemployment error',
         'Employed estimates', 'Employed error', 
         'Agriculture, forestry, fishing and hunting, and mining estimates',
         'Agriculture, forestry, fishing and hunting, and mining error',
         'Construction estimates', 'Construction error', 'Manufacturing estimates',
         'Manufacturing error', 'Wholesale trade estimates', 'Wholesale trade error',
         'Retail trade estimates', 'Retail trade error', 
         'Transportation and warehousing, and utilities estimates',
         'Transportation and warehousing, and utilities error',
         'Information estimates', 'Information error', 
         'Finance and insurance, and real estate and rental and leasing estimates',
         'Finance and insurance, and real estate and rental and leasing error',
         'Professional, scientific, and management, and administrative and waste management services estimates',
         'Professional, scientific, and management, and administrative and waste management services error',
         'Educational services, and health care and social assistance estimates',
         'Educational services, and health care and social assistance error',
         'Arts, entertainment, and recreation, and accommodation and food services estimates',
         'Arts, entertainment, and recreation, and accommodation and food services error',
         'Other services, except public administration estimates',
         'Other services, except public administration error',
         'Public administration estimates', 'Public administration error',
         'Total households estimates', 'Total households error',
         'Less than 10,000 estimates', 'Less than 10,000 error',
         '10,000 to 14,999 estimates', '10,000 to 14,999 error',
         '15,000 to 24,999 estimates', '15,000 to 24,999 error',
         '25,000 to 34,999 estimates', '25,000 to 34,999 error',
         '35,000 to 49,999 estimates', '35,000 to 49,999 error',
         '50,000 to 74,999 estimates', '50,000 to 74,999 error',
         '75,000 to 99,999 estimates', '75,000 to 99,999 error',
         '100,000 to 149,999 estimates', '100,000 to 149,999 error',
         '150,000 to 199,999 estimates', '150,000 to 199,999 error',
         '200,000 or more estimates', '200,000 or more error']

header_ID = ['GEO_ID', 'NAME',
            'DP03_0003E', 'DP03_0003M', 'DP03_0005E', 'DP03_0005M', 
            'DP03_0032E', 'DP03_0032M', 'DP03_0033E', 'DP03_0033M',
            'DP03_0034E', 'DP03_0034M', 'DP03_0035E', 'DP03_0035M',
            'DP03_0036E', 'DP03_0036M', 'DP03_0037E', 'DP03_0037M',
            'DP03_0038E', 'DP03_0038M', 'DP03_0039E', 'DP03_0039M', 
            'DP03_0040E', 'DP03_0040M', 'DP03_0041E', 'DP03_0041M', 
            'DP03_0042E', 'DP03_0042M', 'DP03_0043E', 'DP03_0043M', 
            'DP03_0044E', 'DP03_0044M', 'DP03_0045E', 'DP03_0045M', 
            'DP03_0051E', 'DP03_0051M', 'DP03_0052E', 'DP03_0052M', 
            'DP03_0053E', 'DP03_0053M', 'DP03_0054E', 'DP03_0054M',
            'DP03_0055E', 'DP03_0055M', 'DP03_0056E', 'DP03_0056M',
            'DP03_0057E', 'DP03_0057M', 'DP03_0058E', 'DP03_0058M',
            'DP03_0059E', 'DP03_0059M', 'DP03_0060E', 'DP03_0060M', 
            'DP03_0061E', 'DP03_0061M']

# create dictionary that assigns the IDs into readable names
header_dict = {header_ID[i]: header[i] for i in range(0, len(header))}

# %%
#formatting the dataset
def census_converter(dataset):
    """A function that takes the census dataset and returns wanted columns"""
    new_dataset = dataset[header_ID]

    return new_dataset
#converting each set into one with correct headers and columns of interest
census_1year = census_converter(census_1year)
census_1year = census_1year.iloc[1:,:]
census_1year.rename(columns = header_dict, inplace = True)

census_5year = census_converter(census_5year)
census_5year = census_5year.iloc[1:,:]
census_5year.rename(columns = header_dict, inplace = True)

# %%
# appending corresponding NTA Codes into the census_5year dataframe

# creating a conversion from NYC boroughs to NY counties
# New York is listed as 'New' to fit with string slicing consistency
boroughs_to_counties = {'New': 'Manhattan',
                        'Queens' : 'Queens',
                        'Kings': 'Brooklyn',
                        'Richmond': 'Staten Island',
                        'Bronx': 'Bronx'}
# create a column holding all the NTA Codes
nta_column = []
for index, row in census_5year.iterrows():
    #split the name into single words, then slice them into singular county name
    # and convert them to boroughs
    county = row['Name'].split()
    county = county[3:]
    county = county[:1]
    county = boroughs_to_counties[county[0]]
    # Find NTA Code using tracts_to_nta dictionary
    nta_column.append(tracts_to_nta[(county, row['GEO_ID'][-6::])])

# %%
# insert the column
census_5year.insert(2, "NTACode", nta_column, True)

# %%
# convert all the estimate data into integers to support operations
for i in range(2, len(header)):
    census_5year[header[i]] = pd.to_numeric(census_5year[header[i]])

# %%
#after successful conversion, we only need the NTA Code, discard other GEO information.
census_5year.drop(['GEO_ID', 'Name'], axis = 1, inplace = True )
census_1year.drop(['GEO_ID', 'Name'], axis = 1, inplace = True)
#summing the 5year data with NTA Codes as a grouping
census_5year = census_5year.groupby('NTACode').sum()

# %%
#Turn the NTA Codes into a column instead of index
census_5year.insert(0, 'NTACode', census_5year.index, True)

# %%
#save the preprocessed census files into preprocessed_data

census_5year.to_csv('../preprocessed_data/census_5year.csv')
census_1year.to_csv('../preprocessed_data/census_1year.csv')

# %%
census_5year
# Out:
#         NTACode  Civilian labor force estimates  Civilian labor force error  \
# NTACode
# BK09       BK09                           14526                        1497
# BK17       BK17                           32882                        4333
# BK19       BK19                           15055                        2388
# BK21       BK21                           11879                        2117
# BK23       BK23                            7945                        1107
# ...         ...                             ...                         ...
# SI37       SI37                           11371                        1716
# SI45       SI45                           10238                        1302
# SI48       SI48                           13187                        1268
# SI54       SI54                           21001                        2486
# SI99       SI99                               0                          24
#
#          Unemployment estimates  Unemployment error  Employed estimates  \
# NTACode
# BK09                        446                 294               14080
# BK17                       2250                1294               30632
# BK19                        893                 659               14162
# BK21                       1529                 773               10350
# BK23                        358                 305                7587
# ...                         ...                 ...                 ...
# SI37                        716                 466               10655
# SI45                        497                 304                9741
# SI48                        627                 316               12560
# SI54                       1248                 679               19753
# SI99                          0                  24                   0
#
#          Employed error  \
# NTACode
# BK09               1471
# BK17               4148
# BK19               2276
# BK21               1921
# BK23               1062
# ...                 ...
# SI37               1661
# SI45               1255
# SI48               1251
# SI54               2341
# SI99                 24
#
#          Agriculture, forestry, fishing and hunting, and mining estimates  \
# NTACode
# BK09                                                    53
# BK17                                                     5
# BK19                                                    48
# BK21                                                    23
# BK23                                                     0
# ...                                                    ...
# SI37                                                     0
# SI45                                                     0
# SI48                                                    12
# SI54                                                     0
# SI99                                                     0
#
#          Agriculture, forestry, fishing and hunting, and mining error  \
# NTACode
# BK09                                                   113
# BK17                                                   244
# BK19                                                   149
# BK21                                                   123
# BK23                                                    58
# ...                                                    ...
# SI37                                                   101
# SI45                                                    65
# SI48                                                    65
# SI54                                                   116
# SI99                                                    24
#
#          Construction estimates  ...  50,000 to 74,999 estimates  \
# NTACode                          ...
# BK09                        212  ...                         899
# BK17                       2048  ...                        3763
# BK19                       1012  ...                        2232
# BK21                        734  ...                        1279
# BK23                        343  ...                        1342
# ...                         ...  ...                         ...
# SI37                        704  ...                        1237
# SI45                        768  ...                        1187
# SI48                        799  ...                        1507
# SI54                       1501  ...                        1931
# SI99                          0  ...                           0
#
#          50,000 to 74,999 error  75,000 to 99,999 estimates  \
# NTACode
# BK09                        437                        1231
# BK17                       1464                        3027
# BK19                        852                        1165
# BK21                        645                         668
# BK23                        469                        1000
# ...                         ...                         ...
# SI37                        537                        1136
# SI45                        480                        1391
# SI48                        569                         970
# SI54                        875                        2305
# SI99                         24                           0
#
#          75,000 to 99,999 error  100,000 to 149,999 estimates  \
# NTACode
# BK09                        518                          1781
# BK17                       1352                          3848
# BK19                        619                          1429
# BK21                        430                          1060
# BK23                        459                           732
# ...                         ...                           ...
# SI37                        525                          1337
# SI45                        562                          1553
# SI48                        393                          1949
# SI54                        932                          3593
# SI99                         24                             0
#
#          100,000 to 149,999 error  150,000 to 199,999 estimates  \
# NTACode
# BK09                          600                          1570
# BK17                         1478                          1967
# BK19                          712                           727
# BK21                          521                           279
# BK23                          360                           383
# ...                           ...                           ...
# SI37                          521                           562
# SI45                          512                           859
# SI48                          607                          1241
# SI54                         1085                          1779
# SI99                           24                             0
#
#          150,000 to 199,999 error  200,000 or more estimates  \
# NTACode
# BK09                          556                       3634
# BK17                         1041                       1888
# BK19                          510                        667
# BK21                          215                        288
# BK23                          277                        264
# ...                           ...                        ...
# SI37                          359                        523
# SI45                          356                        612
# SI48                          501                        947
# SI54                          719                       1726
# SI99                           24                          0
#
#          200,000 or more error
# NTACode
# BK09                       779
# BK17                       954
# BK19                       375
# BK21                       265
# BK23                       180
# ...                        ...
# SI37                       343
# SI45                       313
# SI48                       377
# SI54                       778
# SI99                        24
#
# [195 rows x 55 columns]
