# %% [markdown]
# # Extracting and Unzipping Data

# %% [markdown]
# # referenced from Akira's git, code to download the data directly from NYC website
# from os.path import getsize
# from urllib.request import urlretrieve
#
# output_dir = "../raw_data"
# fname_templates = "yellow_tripdata_2018"
#
# for m in range(1, 13):
#     month = str(m).zfill(2)
#     out = f'{fname_template}-{month}.csv'
#     url = f"https://s3.amazonaws.com/nyc-tlc/trip+data/{out}"
#     urlretrieve(url, f"{output_dir}/{out}")
#
#     print(f"Done downloading {out} to {output_dir} with size {getsize(f'{output_dir}/{out}') / 1073741824:.2f}GB")

# %% [markdown]
# # referenced from Akira's git, code to download the data directly from NYC website
# from os.path import getsize
# from urllib.request import urlretrieve
#
# output_dir = "../raw_data"
# fname_template = "yellow_tripdata_2019"
#
# for m in range(1, 13):
#     month = str(m).zfill(2)
#     out = f'{fname_template}-{month}.csv'
#     url = f"https://s3.amazonaws.com/nyc-tlc/trip+data/{out}"
#     urlretrieve(url, f"{output_dir}/{out}")
#
#     print(f"Done downloading {out} to {output_dir} with size {getsize(f'{output_dir}/{out}') / 1073741824:.2f}GB")

# %%
#unzipping the taxi zones, NTA and census files
import zipfile

directory = "../raw_data_lite/"
taxi_zones = f"{directory}taxi_zones.zip"
nta = f"{directory}nynta_21b.zip"
census_1year = f"{directory}2018 1-year estimates.zip"
census_5year = f"{directory}2018 5-year estimates.zip"
zipfiles = (taxi_zones, nta, census_1year, census_5year)
for file in zipfiles:
    with zipfile.ZipFile(file) as z:
        # make sure they are in the same directory
        z.extractall("../raw_data_lite/")

# %%
#importing census data and census tracts data
import pandas as pd

census_tracts = pd.read_excel(f"{directory}nyc2010census_tabulation_equiv.xlsx")
census_1year = pd.read_csv(f"{directory}ACSDP1Y2018.DP03_data_with_overlays_2021-08-03T213532.csv")
census_5year = pd.read_csv(f"{directory}ACSDP5Y2018.DP03_data_with_overlays_2021-08-03T221820.csv")
# Out:
# /home/binhducvu/jupyterenv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (2,3,4,6,7,10,11,14,15,18,19,22,23,26,27,30,31,32,38,39,40,42,43,46,47,50,51,54,55,56,58,59,62,63,64,66,67,70,71,72,74,75,78,79,82,83,86,87,90,91,94,95,102,103,104,106,107,110,111,114,115,118,119,122,123,126,127,128,130,131,134,135,138,139,142,143,146,147,150,151,154,155,158,159,162,163,166,167,170,171,174,175,178,179,182,183,184,186,187,190,191,194,195,198,199,202,203,204,206,207,210,211,214,215,218,219,222,223,226,227,230,231,234,235,238,239,242,243,254,255,262,263,270,271,278,279,286,287,294,295,298,299,300,302,303,306,307,310,311,314,315,318,319,322,323,326,327,330,331,334,335,338,339,354,355,356,378,379,380,382,383,386,387,390,391,394,395,398,399,400,402,403,406,407,408,410,411,412,414,415,416,418,419,422,423,426,427,430,431,434,435,436,438,439,442,443,446,447,450,451,454,455,456,458,459,462,463,466,467,470,471) have mixed types.Specify dtype option on import or se
# ...

# %%
import geopandas as gpd
#converting the NTA and taxi zones data into geojson files
taxi_zones_shp = gpd.read_file(f"{directory}taxi_zones.shp")
taxi_zones_shp.to_file(f"{directory}taxi_zones.geojson", drivers = 'GeoJSON')

nta_shp = gpd.read_file(f"{directory}nynta_21b/nynta.shp")
nta_shp.to_file(f"{directory}nta.geojson", drivers = 'GeoJSON')
#reading the files in as dataframes
taxi_zones = gpd.read_file(f"{directory}taxi_zones.geojson")
nta = gpd.read_file(f"{directory}nta.geojson")
# Out:
# /home/binhducvu/jupyterenv/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %%
# Importing and starting a spark session
from pyspark.sql import SparkSession
from pyspark import SparkContext
#Supress warnings
spark = SparkSession.builder.getOrCreate()
sc = SparkContext.getOrCreate()
sc.setLogLevel('WARN')

spark.conf.set('spark.sql.execution.arrow.pyspark.enabled', True)
#Make the spark files present well
spark.conf.set('spark.sql.repl.eagerEval.enabled', True)
# Out:
# 21/08/04 22:37:37 WARN Utils: Your hostname, LAPTOP-D5HGLKLK resolves to a loopback address: 127.0.1.1; using 172.24.151.17 instead (on interface eth0)
# 21/08/04 22:37:37 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 21/08/04 22:37:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
# reference from Akira Wang's Github
#forming a schema for the dataframes
import pyspark.sql.functions as F
from pyspark.sql.types import *
from pyspark.sql.functions import col

ints = ('VendorID', 'passenger_count', 'RateCodeID', 'RatecodeID','payment_type', 'PULocationID', 'DOLocationID')
doubles = ('trip_distance', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount'
          , 'congestion_surcharge')
strings = ('store_and_fwd_flag',)
dtimes = ('tpep_pickup_datetime', 'tpep_dropoff_datetime')


dtypes = {column: IntegerType() for column in ints}
dtypes.update({column: DoubleType() for column in doubles})
dtypes.update({column: StringType() for column in strings})
dtypes.update({column: TimestampType() for column in dtimes})

# %%
taxi_dir = "../raw_data/yellow_tripdata_20"
#Using a dataset to form the schema
sdf = spark.read.csv(f"{taxi_dir}18-01.csv", header = True)

schema = StructType()
for column in sdf.columns:
    schema.add(column, # column name
               dtypes[column], # data type
               True # is nullable?
              )

# %%
#importing the taxi datasets in dictionaries with schemas


taxi18 = {'taxi18-' + str(i).zfill(2): spark.read.csv(f"{taxi_dir}18-{str(i).zfill(2)}.csv",
                                                     header = True, schema = schema) for i in range(1, 13)}
taxi19 = {'taxi19-' + str(i).zfill(2): spark.read.csv(f"{taxi_dir}19-{str(i).zfill(2)}.csv",
                                                     header = True, schema = schema) for i in range(1, 13)}

# %% [markdown]
# # Preprocessing the data

# %%
#merging the taxi zones and the NTA into a new dataframe
zones = gpd.sjoin(taxi_zones, nta, how = 'right')
zones
# Out:
#      index_left  OBJECTID  Shape_Leng_x  Shape_Area_x  \
# 0            20        21      0.115974      0.000380
# 0            21        22      0.126170      0.000472
# 0            25        26      0.123548      0.000534
# 0            66        67      0.099747      0.000394
# 0            88        89      0.122795      0.000448
# ..          ...       ...           ...           ...
# 194         237       238      0.060109      0.000185
# 194         238       239      0.063626      0.000205
# 194         242       243      0.094331      0.000438
# 194         243       244      0.080569      0.000360
# 194         260       261      0.027120      0.000034
#
#                          zone  LocationID    borough  BoroCode   BoroName  \
# 0            Bensonhurst East          21   Brooklyn         3   Brooklyn
# 0            Bensonhurst West          22   Brooklyn         3   Brooklyn
# 0                Borough Park          26   Brooklyn         3   Brooklyn
# ...

# %%
import numpy as np

census_1year.replace('(X)', np.nan)
census_5year.replace('(X)', np.nan)
# Out:
#                     GEO_ID                                            NAME  \
# 0                       id                            Geographic Area Name
# 1     1400000US36005000100          Census Tract 1, Bronx County, New York
# 2     1400000US36005000200          Census Tract 2, Bronx County, New York
# 3     1400000US36005000400          Census Tract 4, Bronx County, New York
# 4     1400000US36005001600         Census Tract 16, Bronx County, New York
# ...                    ...                                             ...
# 2163  1400000US36085030302  Census Tract 303.02, Richmond County, New York
# 2164  1400000US36085031901  Census Tract 319.01, Richmond County, New York
# 2165  1400000US36085031902  Census Tract 319.02, Richmond County, New York
# 2166  1400000US36085032300     Census Tract 323, Richmond County, New York
# 2167  1400000US36085990100    Census Tract 9901, Richmond County, New York
#
#                                              DP03_0001E  \
# ...

# %%
census_tracts
# Out:
#                                              Unnamed: 0  \
# 0     New York City 2010 Census Tract to Neighborhoo...
# 1                                                   NaN
# 2                                               Borough
# 3                                                   NaN
# 4                                                 Bronx
# ...                                                 ...
# 2167                                      Staten Island
# 2168                                      Staten Island
# 2169                                      Staten Island
# 2170                                      Staten Island
# 2171                                      Staten Island
#
#                                Unnamed: 1             Unnamed: 2  \
# 0                                     NaN                    NaN
# 1                                     NaN                    NaN
# 2     2010 Census Bureau FIPS County Code  2010 NYC Borough Code
# ...

# %%
#Cut out the first 4 rows
census_tracts = census_tracts.iloc[4:,:]
census_tracts
# Out:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 4             Bronx        005          2     031000       3704       BX31
# 5             Bronx        005          2     031200       3704       BX31
# 6             Bronx        005          2     031400       3704       BX31
# 7             Bronx        005          2     031600       3704       BX31
# 8             Bronx        005          2     031800       3704       BX31
# ...             ...        ...        ...        ...        ...        ...
# 2167  Staten Island        085          5     016901       3903       SI07
# 2168  Staten Island        085          5     018701       3903       SI07
# 2169  Staten Island        085          5     018901       3903       SI07
# 2170  Staten Island        085          5     019700       3903       SI07
# 2171  Staten Island        085          5     020100       3903       SI07
#
#                    Unnamed: 6
# 4     Allerton-Pelham Gardens
# ...

# %%
#Create a dictionary for tract code -> nta (code in col 3, nta in col 4)
tracts_to_nta = {}

for index, row in census_tracts.iterrows():
    tracts_to_nta[row['Unnamed: 3']] = row['Unnamed: 5']

# %%
tracts_to_nta
# Out:
# {'031000': 'BX31',
#  '031200': 'BX31',
#  '031400': 'BK26',
#  '031600': 'BX31',
#  '031800': 'BX31',
#  '032600': 'BK21',
#  '034200': 'BK21',
#  '034400': 'BX31',
#  '034800': 'BK21',
#  '035000': 'BK23',
#  '036000': 'BX31',
#  '023702': 'BX05',
#  '039901': 'BX05',
#  '039902': 'BX05',
#  '040100': 'QN26',
#  '040302': 'BX05',
#  '040501': 'BX05',
#  '040502': 'BX05',
#  '040702': 'BX05',
#  '041100': 'QN25',
#  '041300': 'QN25',
#  '041500': 'QN25',
#  '038700': 'BK35',
#  '038900': 'BK78',
#  '039100': 'BK78',
#  '039300': 'BK78',
#  '039700': 'BK78',
#  '032400': 'BX07',
#  '032800': 'QN66',
#  '033000': 'QN02',
#  '033201': 'BX07',
#  '033202': 'BX07',
#  '033600': 'BK21',
#  '033800': 'BX07',
#  '034000': 'BK21',
#  '014500': 'QN70',
#  '014701': 'BX01',
#  '014702': 'BX01',
#  '016500': 'MN12',
#  '016700': 'MN12',
#  '016900': 'QN31',
#  '038500': 'BK35',
#  '039500': 'BK78',
#  '030200': 'BK29',
#  '046201': 'BK42',
#  '046202': 'BK46',
#  '006000': 'MN50',
# ...

# %%
header = ['GEO_ID', 'Name', 
         'Civilian labor force estimates', 'Civilian labor force error',
         'Unemployment estimates', 'Unemployment error',
         'Employed estimates', 'Employed error', 
         'Agriculture, forestry, fishing and hunting, and mining estimates',
         'Agriculture, forestry, fishing and hunting, and mining error',
         'Construction estimates', 'Construction error', 'Manufacturing estimates',
         'Manufacturing error', 'Wholesale trade estimates', 'Wholesale trade error',
         'Retail trade estimates', 'Retail trade error', 
         'Transportation and warehousing, and utilities estimates',
         'Transportation and warehousing, and utilities error',
         'Information estimates', 'Information error', 
         'Finance and insurance, and real estate and rental and leasing estimates',
         'Finance and insurance, and real estate and rental and leasing error',
         'Professional, scientific, and management, and administrative and waste management services estimates',
         'Professional, scientific, and management, and administrative and waste management services error',
         'Educational services, and health care and social assistance estimates',
         'Educational services, and health care and social assistance error',
         'Arts, entertainment, and recreation, and accommodation and food services estimates',
         'Arts, entertainment, and recreation, and accommodation and food services error',
         'Other services, except public administration estimates',
         'Other services, except public administration error',
         'Public administration estimates', 'Public administration error',
         'Total households estimates', 'Total households error',
         'Less than 10,000 estimates', 'Less than 10,000 error',
         '10,000 to 14,999 estimates', '10,000 to 14,999 error',
         '15,000 to 24,999 estimates', '15,000 to 24,999 error',
         '25,000 to 34,999 estimates', '25,000 to 34,999 error',
         '35,000 to 49,999 estimates', '35,000 to 49,999 error',
         '50,000 to 74,999 estimates', '50,000 to 74,999 error',
         '100,000 to 149,999 estimates', '100,000 to 149,999 error',
         '150,000 to 199,999 estimates', '150,000 to 199,999 error',
         '200,000 or more estimates', '200,000 or more error']

header_ID = ['GEO_ID', 'NAME',
            'DP03_0003E', 'DP03_0003M', 'DP03_0005E', 'DP03_0005M', 
            'DP03_0032E', 'DP03_0032M', 'DP03_0033E', 'DP03_0033M',
            'DP03_0034E', 'DP03_0034M', 'DP03_0035E', 'DP03_0035M',
            'DP03_0036E', 'DP03_0036M', 'DP03_0037E', 'DP03_0037M',
            'DP03_0037E', 'DP03_0037M', 'DP03_0038E', 'DP03_0038M',
            'DP03_0039E', 'DP03_0039M', 'DP03_0040E', 'DP03_0040M',
            'DP03_0041E', 'DP03_0041M', 'DP03_0042E', 'DP03_0042M',
            'DP03_0043E', 'DP03_0043E', 'DP03_0044E', 'DP03_0044M',
            'DP03_0045E', 'DP03_0045M', 'DP03_0051E', 'DP03_0051M',
            'DP03_0052E', 'DP03_0052E', 'DP03_0053E', 'DP03_0054M',
            'DP03_0055E', 'DP03_0055E', 'DP03_0056E', 'DP03_0056M',
            'DP03_0057E', 'DP03_0058E', 'DP03_0059E', 'DP03_0059M',
            'DP03_0060E', 'DP03_0060M', 'DP03_0061E', 'DP03_0061M']

header_dict = {header_ID[i]:header[i] for i in range(0, len(header))}

# %%
#create a new dataframe to store the aggregated data from census
# variables of interest: population in civillian labor force, unemployed in labor force
# industry job distributions, and family income distributions, with all their estimates 
# and margin of errors, where possible
# column keys are found from inspection.

def census_converter(dataset):
    """A function that takes the census dataset and returns wanted columns"""
    new_dataset = dataset[['GEO_ID', 'NAME',
                            'DP03_0003E', 'DP03_0003M', 'DP03_0005E', 'DP03_0005M', 
                            'DP03_0032E', 'DP03_0032M', 'DP03_0033E', 'DP03_0033M',
                            'DP03_0034E', 'DP03_0034M', 'DP03_0035E', 'DP03_0035M',
                            'DP03_0036E', 'DP03_0036M', 'DP03_0037E', 'DP03_0037M',
                            'DP03_0037E', 'DP03_0037M', 'DP03_0038E', 'DP03_0038M',
                            'DP03_0039E', 'DP03_0039M', 'DP03_0040E', 'DP03_0040M',
                            'DP03_0041E', 'DP03_0041M', 'DP03_0042E', 'DP03_0042M',
                            'DP03_0043E', 'DP03_0043E', 'DP03_0044E', 'DP03_0044M',
                            'DP03_0045E', 'DP03_0045M', 'DP03_0051E', 'DP03_0051M',
                            'DP03_0052E', 'DP03_0052E', 'DP03_0053E', 'DP03_0054M',
                            'DP03_0055E', 'DP03_0055E', 'DP03_0056E', 'DP03_0056M',
                            'DP03_0057E', 'DP03_0058E', 'DP03_0059E', 'DP03_0059M',
                            'DP03_0060E', 'DP03_0060M', 'DP03_0061E', 'DP03_0061M']]

    return new_dataset

census_1year = census_converter(census_1year)
census_1year = census_1year.iloc[1:,:]
census_1year.rename(columns = header_dict, inplace = True)

census_5year = census_converter(census_5year)
census_5year = census_5year.iloc[1:,:]
census_5year.rename(columns = header_dict, inplace = True)

# %%
census_1year
# Out:
#            GEO_ID                       Name Population estimates  \
# 1  0500000US36005     Bronx County, New York               666788
# 2  0500000US36047     Kings County, New York              1300711
# 3  0500000US36061  New York County, New York               948539
# 4  0500000US36081    Queens County, New York              1202385
# 5  0500000US36085  Richmond County, New York               224531
#
#   Population error Unemployment estimates Unemployment error  \
# 1             8260                  67584               5163
# 2             7713                  63329               4311
# 3            10316                  46659               4173
# 4             8993                  62447               4667
# 5             5189                   9201               2107
#
#   Employed estimates Employed error  \
# 1             599204           8654
# 2            1237382           8425
# 3             901880           9870
# 4            1139938           9197
# ...

# %%
census_5year
# Out:
#                     GEO_ID                                            Name  \
# 1     1400000US36005000100          Census Tract 1, Bronx County, New York
# 2     1400000US36005000200          Census Tract 2, Bronx County, New York
# 3     1400000US36005000400          Census Tract 4, Bronx County, New York
# 4     1400000US36005001600         Census Tract 16, Bronx County, New York
# 5     1400000US36005001900         Census Tract 19, Bronx County, New York
# ...                    ...                                             ...
# 2163  1400000US36085030302  Census Tract 303.02, Richmond County, New York
# 2164  1400000US36085031901  Census Tract 319.01, Richmond County, New York
# 2165  1400000US36085031902  Census Tract 319.02, Richmond County, New York
# 2166  1400000US36085032300     Census Tract 323, Richmond County, New York
# 2167  1400000US36085990100    Census Tract 9901, Richmond County, New York
#
#      Population estimates Population error Unemployment estimates  \
# ...

# %%
#appending NTA zones into the census dataframe

nta_column = []
for index, row in census_5year.iterrows():
    nta_column.append(tracts_to_nta[row['GEO_ID'][-6::]])

# %%
len(nta_column)
# Out:
# 2167

# %%
census_5year.insert(2, "NTA_Zone", nta_column, True)

# %%
census_5year
# Out:
#                     GEO_ID                                            Name  \
# 1     1400000US36005000100          Census Tract 1, Bronx County, New York
# 2     1400000US36005000200          Census Tract 2, Bronx County, New York
# 3     1400000US36005000400          Census Tract 4, Bronx County, New York
# 4     1400000US36005001600         Census Tract 16, Bronx County, New York
# 5     1400000US36005001900         Census Tract 19, Bronx County, New York
# ...                    ...                                             ...
# 2163  1400000US36085030302  Census Tract 303.02, Richmond County, New York
# 2164  1400000US36085031901  Census Tract 319.01, Richmond County, New York
# 2165  1400000US36085031902  Census Tract 319.02, Richmond County, New York
# 2166  1400000US36085032300     Census Tract 323, Richmond County, New York
# 2167  1400000US36085990100    Census Tract 9901, Richmond County, New York
#
# ...

# %%
# Out:
#      BoroCode   BoroName CountyFIPS NTACode  \
# 0           3   Brooklyn        047    BK88
# 1           4     Queens        081    QN51
# 2           4     Queens        081    QN27
# 3           3   Brooklyn        047    BK25
# 4           4     Queens        081    QN41
# ..        ...        ...        ...     ...
# 190         1  Manhattan        061    MN06
# 191         1  Manhattan        061    MN13
# 192         1  Manhattan        061    MN15
# 193         1  Manhattan        061    MN01
# 194         1  Manhattan        061    MN99
#
#                                         NTAName     Shape_Leng    Shape_Area  \
# 0                                  Borough Park   39247.227807  5.400502e+07
# 1                                   Murray Hill   33266.904842  5.248828e+07
# 2                                 East Elmhurst   19816.711907  1.972685e+07
# 3                                     Homecrest   27514.022550  2.999197e+07
# ...

# %%
# Out:
#      BoroCode       BoroName CountyFIPS NTACode  \
# 182         5  Staten Island        085    SI12
#
#                                                NTAName    Shape_Leng  \
# 182  Mariner's Harbor-Arlington-Port Ivory-Granitev...  71306.752688
#
#        Shape_Area                                           geometry
# 182  8.950232e+07  MULTIPOLYGON (((939997.095 173013.579, 939915....
